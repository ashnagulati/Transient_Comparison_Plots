# %% [markdown]
# ## Kinetic energy of fastest moving ejecta - ejecta velocity plot

# %%
import pandas as pd
import numpy as np

# %%
df_other_trans=pd.read_csv("GW190814 transient observational parameter study - Ek vs Gammabeta.csv")
df_other_trans
# Out:
#                        Name  beta  Lorentz factor    Gamma_beta       Energy  \
# 0                  SN 2008D   NaN             NaN          0.25     1.00E+48
# 1                 SN 2007gr  0.20             NaN  0.2041241452     2.00E+46
# 2                   SN2003L  0.20             NaN  0.2041241452     1.00E+48
# 3                  SN2012au  0.20             NaN  0.2041241452     1.00E+47
# 4                  SN2012ap  0.70             NaN  0.9801960588     1.60E+49
# ..                      ...   ...             ...           ...          ...
# 142                NGC 4552   NaN             2.3   2.071231518  4.66452E+50
# 143                NGC 4579   NaN             2.3   2.071231518  4.55834E+50
# 144                NGC 4594   NaN             2.3   2.071231518  5.73861E+50
# 145  FIRST J141918.9+394036  0.06             NaN          0.06        5E+50
# 146  FIRST J141918.9+394036  0.15             NaN         >0.15       >1E+50
#
#       Type Relativicity                Ref
# 0      SNe      Non-rel     Soderberg,2008
# 1      SNe      Non-rel    Soderberg,2010b
# 2      SNe      Non-rel    Soderberg, 2005
# 3      SNe      Non-rel       Kamble, 2013
# 4      SNe      Non-rel  Chakroborti, 2014
# ..     ...          ...                ...
# 142  LLAGN          NaN           Ma. 2014
# 143  LLAGN          NaN           Ma. 2014
# 144  LLAGN          NaN           Ma. 2014
# 145     OA          NaN                NaN
# 146     OA          NaN                NaN
#
# [147 rows x 8 columns]

# %%
pwd
# Out:
# '/home/ashnagulati/GW190814_transient'

# %%
import pandas as pd
import numpy as np

# Load the CSV
df_equi = pd.read_csv("E_gammabeta_equipartition.csv")

# Add/modify columns
df_equi["beta"] = np.nan * np.ones(len(df_equi))        # fill with NaNs
df_equi["Lorentz factor"] = np.nan * np.ones(len(df_equi))   
df_equi["Type"] = df_equi["Name"]
df_equi["Relativicity"] = ["Non-rel"] * len(df_equi)
df_equi["Ref"] = ["This work"] * len(df_equi)

# Rename column
df_equi.rename(columns={"E_center": "Energy"}, inplace=True)

# Show selected columns
df_equi_subset = df_equi[["Name", "beta", "Lorentz factor", "Gamma_beta", "Energy", "Type", "Relativicity","Ref"]]
df_equi_subset
# Out:
#                     Name  beta  Lorentz factor  Gamma_beta  \
# 0   ASKAP J0055-2558_sph   NaN             NaN    0.286674
# 1   ASKAP J0055-2558_sph   NaN             NaN    0.280754
# 2   ASKAP J0055-2558_sph   NaN             NaN    0.268510
# 3   ASKAP J0055-2558_sph   NaN             NaN    0.254500
# 4   ASKAP J0055-2558_sph   NaN             NaN    0.226554
# 5   ASKAP J0055-2558_sph   NaN             NaN    0.225530
# 6   ASKAP J0055-2558_sph   NaN             NaN    0.212764
# 7   ASKAP J0055-2558_sph   NaN             NaN    0.201474
# 8   ASKAP J0055-2558_sph   NaN             NaN    0.190952
# 9    ASKAP J0055-2558_c5   NaN             NaN    1.085620
# 10   ASKAP J0055-2558_c5   NaN             NaN    1.069106
# 11   ASKAP J0055-2558_c5   NaN             NaN    1.034712
# 12   ASKAP J0055-2558_c5   NaN             NaN    0.994923
# 13   ASKAP J0055-2558_c5   NaN             NaN    0.913938
# 14   ASKAP J0055-2558_c5   NaN             NaN    0.910926
# 15   ASKAP J0055-2558_c5   NaN             NaN    0.873047
# 16   ASKAP J0055-2558_c5   NaN             NaN    0.839034
# 17   ASKAP J0055-2558_c5   NaN             NaN    0.806849
# 18  ASKAP J0055-2558_c15   NaN             NaN    0.617592
# 19  ASKAP J0055-2558_c15   NaN             NaN    0.606908
# 20  ASKAP J0055-2558_c15   NaN             NaN    0.584684
# 21  ASKAP J0055-2558_c15   NaN             NaN    0.559029
# 22  ASKAP J0055-2558_c15   NaN             NaN    0.507040
# 23  ASKAP J0055-2558_c15   NaN             NaN    0.505113
# 24  ASKAP J0055-2558_c15   NaN             NaN    0.480933
# 25  ASKAP J0055-2558_c15   NaN             NaN    0.459308
# 26  ASKAP J0055-2558_c15   NaN             NaN    0.438931
# 27  ASKAP J0055-2558_c30   NaN             NaN    0.413943
# 28  ASKAP J0055-2558_c30   NaN             NaN    0.406048
# 29  ASKAP J0055-2558_c30   NaN             NaN    0.389667
# 30  ASKAP J0055-2558_c30   NaN             NaN    0.370834
# 31  ASKAP J0055-2558_c30   NaN             NaN    0.332952
# 32  ASKAP J0055-2558_c30   NaN             NaN    0.331556
# 33  ASKAP J0055-2558_c30   NaN             NaN    0.314090
# 34  ASKAP J0055-2558_c30   NaN             NaN    0.298555
# 35  ASKAP J0055-2558_c30   NaN             NaN    0.283997
#
#                            Energy                  Type Relativicity  \
# 0   3.487e+50/6.741e+49/4.008e+51  ASKAP J0055-2558_sph      Non-rel
# 1   3.660e+50/7.077e+49/4.208e+51  ASKAP J0055-2558_sph      Non-rel
# 2   4.002e+50/7.738e+49/4.601e+51  ASKAP J0055-2558_sph      Non-rel
# 3   4.281e+50/8.276e+49/4.921e+51  ASKAP J0055-2558_sph      Non-rel
# 4   4.448e+50/8.599e+49/5.113e+51  ASKAP J0055-2558_sph      Non-rel
# 5   4.488e+50/8.677e+49/5.159e+51  ASKAP J0055-2558_sph      Non-rel
# 6   4.431e+50/8.566e+49/5.093e+51  ASKAP J0055-2558_sph      Non-rel
# 7   4.292e+50/8.298e+49/4.934e+51  ASKAP J0055-2558_sph      Non-rel
# 8   4.116e+50/7.957e+49/4.731e+51  ASKAP J0055-2558_sph      Non-rel
# 9   1.034e+52/2.000e+51/1.189e+53   ASKAP J0055-2558_c5      Non-rel
# 10  1.086e+52/2.100e+51/1.248e+53   ASKAP J0055-2558_c5      Non-rel
# 11  1.187e+52/2.296e+51/1.365e+53   ASKAP J0055-2558_c5      Non-rel
# 12  1.270e+52/2.455e+51/1.460e+53   ASKAP J0055-2558_c5      Non-rel
# 13  1.320e+52/2.551e+51/1.517e+53   ASKAP J0055-2558_c5      Non-rel
# 14  1.332e+52/2.574e+51/1.531e+53   ASKAP J0055-2558_c5      Non-rel
# 15  1.314e+52/2.541e+51/1.511e+53   ASKAP J0055-2558_c5      Non-rel
# 16  1.273e+52/2.462e+51/1.464e+53   ASKAP J0055-2558_c5      Non-rel
# 17  1.221e+52/2.361e+51/1.404e+53   ASKAP J0055-2558_c5      Non-rel
# 18  2.707e+51/5.233e+50/3.112e+52  ASKAP J0055-2558_c15      Non-rel
# 19  2.842e+51/5.494e+50/3.267e+52  ASKAP J0055-2558_c15      Non-rel
# 20  3.107e+51/6.007e+50/3.572e+52  ASKAP J0055-2558_c15      Non-rel
# 21  3.324e+51/6.425e+50/3.820e+52  ASKAP J0055-2558_c15      Non-rel
# 22  3.453e+51/6.676e+50/3.969e+52  ASKAP J0055-2558_c15      Non-rel
# 23  3.485e+51/6.737e+50/4.005e+52  ASKAP J0055-2558_c15      Non-rel
# 24  3.440e+51/6.650e+50/3.954e+52  ASKAP J0055-2558_c15      Non-rel
# 25  3.332e+51/6.443e+50/3.831e+52  ASKAP J0055-2558_c15      Non-rel
# 26  3.195e+51/6.178e+50/3.673e+52  ASKAP J0055-2558_c15      Non-rel
# 27  1.162e+51/2.246e+50/1.335e+52  ASKAP J0055-2558_c30      Non-rel
# 28  1.220e+51/2.358e+50/1.402e+52  ASKAP J0055-2558_c30      Non-rel
# 29  1.334e+51/2.578e+50/1.533e+52  ASKAP J0055-2558_c30      Non-rel
# 30  1.426e+51/2.758e+50/1.640e+52  ASKAP J0055-2558_c30      Non-rel
# 31  1.482e+51/2.865e+50/1.704e+52  ASKAP J0055-2558_c30      Non-rel
# 32  1.496e+51/2.891e+50/1.719e+52  ASKAP J0055-2558_c30      Non-rel
# 33  1.476e+51/2.854e+50/1.697e+52  ASKAP J0055-2558_c30      Non-rel
# 34  1.430e+51/2.765e+50/1.644e+52  ASKAP J0055-2558_c30      Non-rel
# 35  1.371e+51/2.651e+50/1.576e+52  ASKAP J0055-2558_c30      Non-rel
#
#           Ref
# 0   This work
# 1   This work
# 2   This work
# 3   This work
# 4   This work
# 5   This work
# 6   This work
# 7   This work
# 8   This work
# 9   This work
# 10  This work
# 11  This work
# 12  This work
# 13  This work
# 14  This work
# 15  This work
# 16  This work
# 17  This work
# 18  This work
# 19  This work
# 20  This work
# 21  This work
# 22  This work
# 23  This work
# 24  This work
# 25  This work
# 26  This work
# 27  This work
# 28  This work
# 29  This work
# 30  This work
# 31  This work
# 32  This work
# 33  This work
# 34  This work
# 35  This work

# %%
all_data=pd.concat([df_other_trans,df_equi_subset])
all_data
# Out:
#                     Name  beta  Lorentz factor    Gamma_beta  \
# 0               SN 2008D   NaN             NaN          0.25
# 1              SN 2007gr   0.2             NaN  0.2041241452
# 2                SN2003L   0.2             NaN  0.2041241452
# 3               SN2012au   0.2             NaN  0.2041241452
# 4               SN2012ap   0.7             NaN  0.9801960588
# ..                   ...   ...             ...           ...
# 31  ASKAP J0055-2558_c30   NaN             NaN      0.332952
# 32  ASKAP J0055-2558_c30   NaN             NaN      0.331556
# 33  ASKAP J0055-2558_c30   NaN             NaN       0.31409
# 34  ASKAP J0055-2558_c30   NaN             NaN      0.298555
# 35  ASKAP J0055-2558_c30   NaN             NaN      0.283997
#
#                            Energy                  Type Relativicity  \
# 0                        1.00E+48                   SNe      Non-rel
# 1                        2.00E+46                   SNe      Non-rel
# 2                        1.00E+48                   SNe      Non-rel
# 3                        1.00E+47                   SNe      Non-rel
# 4                        1.60E+49                   SNe      Non-rel
# ..                            ...                   ...          ...
# 31  1.482e+51/2.865e+50/1.704e+52  ASKAP J0055-2558_c30      Non-rel
# 32  1.496e+51/2.891e+50/1.719e+52  ASKAP J0055-2558_c30      Non-rel
# 33  1.476e+51/2.854e+50/1.697e+52  ASKAP J0055-2558_c30      Non-rel
# 34  1.430e+51/2.765e+50/1.644e+52  ASKAP J0055-2558_c30      Non-rel
# 35  1.371e+51/2.651e+50/1.576e+52  ASKAP J0055-2558_c30      Non-rel
#
#                   Ref
# 0      Soderberg,2008
# 1     Soderberg,2010b
# 2     Soderberg, 2005
# 3        Kamble, 2013
# 4   Chakroborti, 2014
# ..                ...
# 31          This work
# 32          This work
# 33          This work
# 34          This work
# 35          This work
#
# [183 rows x 8 columns]

# %%
np.unique(all_data.Type.values)
# Out:
# array(['ASKAP J0055-2558_c15', 'ASKAP J0055-2558_c30',
#        'ASKAP J0055-2558_c5', 'ASKAP J0055-2558_sph', 'Delayed TDEs',
#        'FBOTs', 'GRBs', 'LLAGN', 'OA', 'SNe', 'Sub-E GRBs', 'TDEs',
#        'TDEs (jetted)'], dtype=object)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# Define your custom styles
plot_style = {
    'GRBs':                     {'marker': 'o', 'alpha': 1, 'size': 70, 'zorder': 1, 'color': "tab:blue"},
    'Sub-E GRBs':               {'marker': 'o', 'alpha': 1, 'size': 70, 'zorder': 2, 'color': "lightblue"},
    'SNe':                      {'marker': 'o', 'alpha': 1, 'size': 70, 'zorder': 1, 'color': "dimgrey"},
    'LLAGN':                      {'marker': 'X', 'alpha': 1, 'size': 90, 'zorder': 1, 'color': "purple"},
    # 'Rel-Sne':        {'marker': 'o', 'alpha': 1, 'size': 40, 'zorder': 2, 'color': "darkgrey"},
    'TDEs (jetted)':            {'marker': 's', 'alpha': 1, 'size': 60, 'zorder': 7, 'color': "darkgreen"},
    'TDEs':                     {'marker': 's', 'alpha': 1, 'size': 60, 'zorder': 7, 'color': "yellowgreen"},
    'Delayed TDEs':             {'marker': 's', 'alpha': 1, 'size': 60, 'zorder': 7, 'color': "darkseagreen"},
    'FBOTs':                    {'marker': 'D', 'alpha': 1, 'size': 60, 'zorder': 50, 'color': "black"},
    'ASKAP J0055-2558_sph': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "peru"},
    'ASKAP J0055-2558_c15': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "gold"},
    'ASKAP J0055-2558_c30': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "orange"},
    'ASKAP J0055-2558_c5': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "red"},
    "OA": {'marker': '*', 'alpha': 0.6, 'size': 100, 'zorder': 100,'color':"black"}
    # 'ASKAP J0055-2558_rel_c15': {'marker': '*', 'alpha': 1, 'size': 100, 'zorder': 100, 'color': "red"},
    # "ASKAP J0055-2558_non_rel": {'marker': 's', 'alpha': 1, 'size': 50, 'zorder': 100, 'color': "red"},
}
special_types_with_boxes = [] #["ASKAP J0055-2558_rel", "ASKAP J0055-2558_non_rel"]

def plot_energy_vs_gamma_beta(all_data):
    fig = plt.figure(figsize=(7, 6))
    ax = plt.gca()

    used_labels = set()

    for (obj_name, obj_type), group in all_data.groupby(['Name', 'Type']):
        style = plot_style.get(obj_type, {'marker': 'o', 'alpha': 0.7, 'size': 30, 'zorder': 1, 'color': 'gray'})

        gamma_beta_list = []
        energy_list = []

        for idx, row in group.iterrows():
            gamma_beta_raw = str(row['Gamma_beta'])
            energy_raw = str(row['Energy'])

            if obj_type in special_types_with_boxes:
                # Special case: draw dashed rectangle
                gamma_beta_low, gamma_beta_high = parse_range(gamma_beta_raw)
                energy_low, energy_high = parse_range(energy_raw)

                width = gamma_beta_high - gamma_beta_low
                height = energy_high - energy_low

                rect = mpatches.Rectangle(
                    (gamma_beta_low, energy_low),
                    width, height,
                    linewidth=1,
                    linestyle='-',  # Dashed rectangle
                    edgecolor=style['color'],
                    facecolor='none',
                    zorder=style['zorder']
                )
                ax.add_patch(rect)

            else:
                gamma_beta_val, gamma_beta_err_low, gamma_beta_err_high = parse_value_with_errors(gamma_beta_raw)
                energy_val, energy_err_low, energy_err_high = parse_value_with_errors(energy_raw)

                gamma_beta_list.append(gamma_beta_val)
                energy_list.append(energy_val)

                gamma_beta_arrow = None
                energy_arrow = None
                if '<' in gamma_beta_raw:
                    gamma_beta_arrow = 'left'
                elif '>' in gamma_beta_raw:
                    gamma_beta_arrow = 'right'
                if '<' in energy_raw:
                    energy_arrow = 'down'
                elif '>' in energy_raw:
                    energy_arrow = 'up'

                if gamma_beta_arrow is None and energy_arrow is None:
                    xerr = np.array([
                        [abs(gamma_beta_val - gamma_beta_err_low)],
                        [abs(gamma_beta_err_high - gamma_beta_val)]
                    ])
                    yerr = np.array([
                        [abs(energy_val - energy_err_low)],
                        [abs(energy_err_high - energy_val)]
                    ])

                    # Draw errorbars without marker
                    ax.errorbar(
                        gamma_beta_val, energy_val,
                        xerr=xerr,
                        yerr=yerr,
                        fmt='none',  # no marker at center
                        ecolor=style['color'],
                        elinewidth=1.5,
                        capsize=3,
                        alpha=style['alpha'],
                        zorder=style['zorder'] 
                    )

                    # Now separately scatter the point
                    ax.scatter(
                        gamma_beta_val, energy_val,
                        marker=style['marker'],
                        color=style['color'],
                        s=style['size'],
                        alpha=style['alpha'],
                        label=obj_type if obj_type not in used_labels else None,
                        zorder=style['zorder'],
                        edgecolor="black"
                    )

                else:
                    # Just scatter + big arrow for limits
                    ax.scatter(
                        gamma_beta_val, energy_val,
                        marker=style['marker'],
                        color=style['color'],
                        s=style['size'],
                        alpha=style['alpha'],
                        label=obj_type if obj_type not in used_labels else None,
                        zorder=style['zorder'],
                        edgecolor="black"
                    )

                    # Draw bigger arrows
                    arrow_dx = 0.4 * gamma_beta_val  # Make arrow longer (40% of x)
                    arrow_dy = 2 * energy_val  # Arrow longer (70% of y)

                    if gamma_beta_arrow:
                        if gamma_beta_arrow == 'left':
                            ax.annotate('', xy=(gamma_beta_val - arrow_dx, energy_val), xytext=(gamma_beta_val, energy_val),
                                        arrowprops=dict(arrowstyle="->", color=style['color'], lw=2))
                        else:
                            ax.annotate('', xy=(gamma_beta_val + arrow_dx, energy_val), xytext=(gamma_beta_val, energy_val),
                                        arrowprops=dict(arrowstyle="->", color=style['color'], lw=2))

                    if energy_arrow:
                        if energy_arrow == 'down':
                            ax.annotate('', xy=(gamma_beta_val, energy_val - arrow_dy), xytext=(gamma_beta_val, energy_val),
                                        arrowprops=dict(arrowstyle="->", color=style['color'], lw=2))
                        else:
                            ax.annotate('', xy=(gamma_beta_val, energy_val + arrow_dy), xytext=(gamma_beta_val, energy_val),
                                        arrowprops=dict(arrowstyle="->", color=style['color'], lw=2))

            used_labels.add(obj_type)

        # After plotting all points for one object, connect them
        if len(gamma_beta_list) >= 2:
            gamma_beta_list, energy_list = zip(*sorted(zip(gamma_beta_list, energy_list)))
            ax.plot(
                gamma_beta_list, energy_list,
                color=style['color'],
                lw=1.5,
                alpha=style['alpha'],
                zorder=style['zorder'] - 2  # Line below scatter
            )

    # Draw vertical line at Gamma_beta = 1
    ax.axvline(x=1, color='black', linestyle='--', linewidth=2, zorder=0)

#     # Add labels for non-relativistic and relativistic regimes
    ax.text(0.35,0.95,r"Non-relativistic",horizontalalignment='left',verticalalignment='center', transform=ax.transAxes,color="black",fontsize="12",fontweight="bold")
    ax.text(0.65,0.95,r"Relativistic",horizontalalignment='left',verticalalignment='center', transform=ax.transAxes,color="black",fontsize="12",fontweight="bold")


    # Build the legend
    label_order = ['ASKAP J0055-2558_non_rel_sph','ASKAP J0055-2558_non_rel_c30',
                   'ASKAP J0055-2558_non_rel_c15','ASKAP J0055-2558_non_rel_c10',
                   'GRBs', 'Sub-E GRBs', 'SNe', 'FBOTs',
                   'TDEs (jetted)', 'TDEs', 'Delayed TDEs','LLAGN']

    handles = [
        mpatches.Patch(color=plot_style[label]['color'], label=label)
        for label in label_order
        if label in used_labels  # only if the label was actually used in the plot
    ]
    ax.legend(
        handles=handles,
        loc='upper center',
        bbox_to_anchor=(0.5, -0.15),
        ncol=3,
        frameon=False,
        fontsize=11,
        handletextpad=0.5,
        columnspacing=1.5
    )

    
    # Set log scales
    ax.set_xscale('log')
    ax.set_yscale('log')

    ax.set_xlabel(r'$\Gamma \beta$', fontsize=16)
    ax.set_ylabel(r'Kinetic Energy (erg)', fontsize=16)

    ax.tick_params(axis='both', colors='black', direction='in', length=7, width=1, labelsize="large")
    ax.tick_params(axis='both', which="minor", colors='black', direction='in', length=5, width=1)

    ax.set_yscale('log')

    from matplotlib.ticker import LogLocator
    ax.yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(2, 10)*0.1, numticks=10))
    ax.yaxis.set_minor_formatter(plt.NullFormatter())

    ax.tick_params(axis='y', which='both', direction='in', length=5, width=1)
    ax.tick_params(axis='both', which="major", colors='black', direction='in', length=7, width=1)


    for spine in ax.spines.values():
        spine.set_linewidth(2)

    plt.tight_layout()
    # plt.show()
    return fig

def parse_value_with_errors(value_str):
    value_str = value_str.strip()
    if '/' in value_str:
        parts = value_str.split('/')
        if len(parts)==2:
            center = float(parts[0])
            err_low = float(parts[1])
            err_u = float(parts[1])
        else:
            center = float(parts[0])
            err_low = float(parts[1])
            err_u = float(parts[2])
        return center, err_low, err_u
    elif '<' in value_str:
        val = float(value_str.replace('<', '').strip())
        return val, val * 0.5, val
    elif '>' in value_str:
        val = float(value_str.replace('>', '').strip())
        return val, val, val * 1.5
    else:
        val = float(value_str)
        return val, val, val

def parse_range(value_str):
    value_str = value_str.strip()
    if '-' in value_str:
        low, high = value_str.split('-')
        return float(low), float(high)
    else:
        raise ValueError(f"Expected a range with '-' but got {value_str}")

# %%
fig=plot_energy_vs_gamma_beta(all_data)

# %%
askap_types = [
    'ASKAP J0055-2558_sph',
    'ASKAP J0055-2558_c15',
    'ASKAP J0055-2558_c30',
    'ASKAP J0055-2558_c5',
    # 'FIRST J141918.9+394036'
]

askap_data = all_data[all_data['Type'].isin(askap_types)]

fig = plot_energy_vs_gamma_beta(askap_data)
plt.show()

# %%
fig.savefig("GW190814_interesting_source_energy_velocity.png",format="png", dpi=150,bbox_inches='tight')
fig.savefig("GW190814_interesting_source_energy_velocity.pdf",format="pdf", dpi=150,bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# Define your custom styles
plot_style = {
    'GRBs':                     {'marker': 'o', 'alpha': 1, 'size': 70, 'zorder': 1, 'color': "tab:blue"},
    'Sub-E GRBs':               {'marker': 'o', 'alpha': 1, 'size': 70, 'zorder': 2, 'color': "lightblue"},
    'SNe':                      {'marker': 'o', 'alpha': 1, 'size': 70, 'zorder': 1, 'color': "dimgrey"},
    'LLAGN':                      {'marker': 'X', 'alpha': 1, 'size': 90, 'zorder': 1, 'color': "purple"},
    # 'Rel-Sne':        {'marker': 'o', 'alpha': 1, 'size': 40, 'zorder': 2, 'color': "darkgrey"},
    'TDEs (jetted)':            {'marker': 's', 'alpha': 1, 'size': 60, 'zorder': 7, 'color': "darkgreen"},
    'TDEs':                     {'marker': 's', 'alpha': 1, 'size': 60, 'zorder': 7, 'color': "yellowgreen"},
    'Delayed TDEs':             {'marker': 's', 'alpha': 1, 'size': 60, 'zorder': 7, 'color': "darkseagreen"},
    'FBOTs':                    {'marker': 'D', 'alpha': 1, 'size': 60, 'zorder': 50, 'color': "black"},
    'ASKAP J0055-2558_sph': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "peru"},
    'ASKAP J0055-2558_c15': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "gold"},
    'ASKAP J0055-2558_c30': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "orange"},
    'ASKAP J0055-2558_c5': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "red"},
    # 'ASKAP J0055-2558_rel_c15': {'marker': '*', 'alpha': 1, 'size': 100, 'zorder': 100, 'color': "red"},
    # "ASKAP J0055-2558_non_rel": {'marker': 's', 'alpha': 1, 'size': 50, 'zorder': 100, 'color': "red"},
}
special_types_with_boxes = [] #["ASKAP J0055-2558_rel", "ASKAP J0055-2558_non_rel"]

def plot_energy_vs_gamma_beta(all_data):
    fig = plt.figure(figsize=(7, 6))
    ax = plt.gca()

    used_labels = set()

    for (obj_name, obj_type), group in all_data.groupby(['Name', 'Type']):
        style = plot_style.get(obj_type, {'marker': 'o', 'alpha': 0.7, 'size': 30, 'zorder': 1, 'color': 'gray'})

        gamma_beta_list = []
        energy_list = []

        for idx, row in group.iterrows():
            gamma_beta_raw = str(row['Gamma_beta'])
            energy_raw = str(row['Energy'])

            if obj_type in special_types_with_boxes:
                # Special case: draw dashed rectangle
                gamma_beta_low, gamma_beta_high = parse_range(gamma_beta_raw)
                energy_low, energy_high = parse_range(energy_raw)

                width = gamma_beta_high - gamma_beta_low
                height = energy_high - energy_low

                rect = mpatches.Rectangle(
                    (gamma_beta_low, energy_low),
                    width, height,
                    linewidth=1,
                    linestyle='-',  # Dashed rectangle
                    edgecolor=style['color'],
                    facecolor='none',
                    zorder=style['zorder']
                )
                ax.add_patch(rect)

            else:
                gamma_beta_val, gamma_beta_err_low, gamma_beta_err_high = parse_value_with_errors(gamma_beta_raw)
                energy_val, energy_err_low, energy_err_high = parse_value_with_errors(energy_raw)

                gamma_beta_list.append(gamma_beta_val)
                energy_list.append(energy_val)

                gamma_beta_arrow = None
                energy_arrow = None
                if '<' in gamma_beta_raw:
                    gamma_beta_arrow = 'left'
                elif '>' in gamma_beta_raw:
                    gamma_beta_arrow = 'right'
                if '<' in energy_raw:
                    energy_arrow = 'down'
                elif '>' in energy_raw:
                    energy_arrow = 'up'

                if gamma_beta_arrow is None and energy_arrow is None:
                    xerr = np.array([
                        [abs(gamma_beta_val - gamma_beta_err_low)],
                        [abs(gamma_beta_err_high - gamma_beta_val)]
                    ])
                    yerr = np.array([
                        [abs(energy_val - energy_err_low)],
                        [abs(energy_err_high - energy_val)]
                    ])

                    # Draw errorbars without marker
                    ax.errorbar(
                        gamma_beta_val, energy_val,
                        xerr=xerr,
                        yerr=yerr,
                        fmt='none',  # no marker at center
                        ecolor=style['color'],
                        elinewidth=1.5,
                        capsize=3,
                        alpha=style['alpha'],
                        zorder=style['zorder'] 
                    )

                    # Now separately scatter the point
                    ax.scatter(
                        gamma_beta_val, energy_val,
                        marker=style['marker'],
                        color=style['color'],
                        s=style['size'],
                        alpha=style['alpha'],
                        label=obj_type if obj_type not in used_labels else None,
                        zorder=style['zorder'],
                        edgecolor="white"
                    )

                else:
                    # Just scatter + big arrow for limits
                    ax.scatter(
                        gamma_beta_val, energy_val,
                        marker=style['marker'],
                        color=style['color'],
                        s=style['size'],
                        alpha=style['alpha'],
                        label=obj_type if obj_type not in used_labels else None,
                        zorder=style['zorder'],
                        edgecolor="white"
                    )

                    # Draw bigger arrows
                    arrow_dx = 0.4 * gamma_beta_val  # Make arrow longer (40% of x)
                    arrow_dy = 2 * energy_val  # Arrow longer (70% of y)

                    if gamma_beta_arrow:
                        if gamma_beta_arrow == 'left':
                            ax.annotate('', xy=(gamma_beta_val - arrow_dx, energy_val), xytext=(gamma_beta_val, energy_val),
                                        arrowprops=dict(arrowstyle="->", color=style['color'], lw=2))
                        else:
                            ax.annotate('', xy=(gamma_beta_val + arrow_dx, energy_val), xytext=(gamma_beta_val, energy_val),
                                        arrowprops=dict(arrowstyle="->", color=style['color'], lw=2))

                    if energy_arrow:
                        if energy_arrow == 'down':
                            ax.annotate('', xy=(gamma_beta_val, energy_val - arrow_dy), xytext=(gamma_beta_val, energy_val),
                                        arrowprops=dict(arrowstyle="->", color=style['color'], lw=2))
                        else:
                            ax.annotate('', xy=(gamma_beta_val, energy_val + arrow_dy), xytext=(gamma_beta_val, energy_val),
                                        arrowprops=dict(arrowstyle="->", color=style['color'], lw=2))

            used_labels.add(obj_type)

        # After plotting all points for one object, connect them
        if len(gamma_beta_list) >= 2:
            gamma_beta_list, energy_list = zip(*sorted(zip(gamma_beta_list, energy_list)))
            ax.plot(
                gamma_beta_list, energy_list,
                color=style['color'],
                lw=1.5,
                alpha=style['alpha'],
                zorder=style['zorder'] - 2  # Line below scatter
            )

        from datetime import datetime

        # Launch date
        launch_date = datetime(2022, 2, 4)

        # Dates corresponding to the three ASKAP observations
        # askap_obs_dates = [
        #     datetime(2024, 3, 10),
        #     datetime(2024, 6, 24),
        #     datetime(2024, 12, 26)
        # ]
        
        # Get unique date strings
        askap_obs_dates = np.unique(df_equi.dateobs)

        # Convert to datetime
        askap_obs_dates = pd.to_datetime(askap_obs_dates)

        # Shift amounts
        time_shifts = [-1000, 500]

        if obj_type.startswith('ASKAP J0055'):
            # Counter to track which epoch we're at
            askap_row_counter = 0

            for idx, row in group.iterrows():
                gamma_beta_raw = str(row['Gamma_beta'])
                energy_raw = str(row['Energy'])

                gamma_beta_val, gamma_beta_err_low, gamma_beta_err_high = parse_value_with_errors(gamma_beta_raw)
                energy_val, energy_err_low, energy_err_high = parse_value_with_errors(energy_raw)

                obs_date = askap_obs_dates[askap_row_counter]
                t_original = (obs_date - launch_date).days

                for delta in time_shifts:
                    t_shifted = t_original - delta
                    print(t_original,t_shifted)
                    if t_shifted <= 0:
                        continue  # skip unphysical

                    gamma_beta_shifted = gamma_beta_val * (t_original / t_shifted)

                    # Plot small vertical line at shifted gamma_beta
                    ax.plot(
                        [gamma_beta_shifted, gamma_beta_shifted],
                        [energy_val*0.9, energy_val*1.1],
                        color=plot_style[obj_type]['color'],
                        lw=1.5,
                        alpha=0.8
                    )

                    # Label the shift
                    ax.text(
                        gamma_beta_shifted,
                        energy_val*1.15,
                        f'{delta:+d} d',
                        ha='center',
                        va='bottom',
                        fontsize=8,
                        rotation=90,
                        color=plot_style[obj_type]['color'],
                        alpha=0.8
                    )

                askap_row_counter += 1

    # Draw vertical line at Gamma_beta = 1
    ax.axvline(x=1, color='black', linestyle='--', linewidth=2, zorder=0)

#     # Add labels for non-relativistic and relativistic regimes
    ax.text(0.35,0.95,r"Non-relativistic",horizontalalignment='left',verticalalignment='center', transform=ax.transAxes,color="black",fontsize="12",fontweight="bold")
    ax.text(0.65,0.95,r"Relativistic",horizontalalignment='left',verticalalignment='center', transform=ax.transAxes,color="black",fontsize="12",fontweight="bold")


    # Build the legend
    label_order = ['ASKAP J0055-2558_non_rel_sph','ASKAP J0055-2558_non_rel_c30',
                   'ASKAP J0055-2558_non_rel_c15','ASKAP J0055-2558_non_rel_c10',
                   'GRBs', 'Sub-E GRBs', 'SNe', 'FBOTs',
                   'TDEs (jetted)', 'TDEs', 'Delayed TDEs','LLAGN']

    handles = [
        mpatches.Patch(color=plot_style[label]['color'], label=label)
        for label in label_order
        if label in used_labels  # only if the label was actually used in the plot
    ]
    ax.legend(
        handles=handles,
        loc='upper center',
        bbox_to_anchor=(0.5, -0.15),
        ncol=3,
        frameon=False,
        fontsize=11,
        handletextpad=0.5,
        columnspacing=1.5
    )

    
    # Set log scales
    ax.set_xscale('log')
    ax.set_yscale('log')

    ax.set_xlabel(r'$\Gamma \beta$', fontsize=16)
    ax.set_ylabel(r'Kinetic Energy (erg)', fontsize=16)

    ax.tick_params(axis='both', colors='black', direction='in', length=7, width=1, labelsize="large")
    ax.tick_params(axis='both', which="minor", colors='black', direction='in', length=5, width=1)

    ax.set_yscale('log')

    from matplotlib.ticker import LogLocator
    ax.yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(2, 10)*0.1, numticks=10))
    ax.yaxis.set_minor_formatter(plt.NullFormatter())

    ax.tick_params(axis='y', which='both', direction='in', length=5, width=1)
    ax.tick_params(axis='both', which="major", colors='black', direction='in', length=7, width=1)


    for spine in ax.spines.values():
        spine.set_linewidth(2)

    plt.tight_layout()
    # plt.show()
    return fig

def parse_value_with_errors(value_str):
    value_str = value_str.strip()
    if '/' in value_str:
        parts = value_str.split('/')
        if len(parts)==2:
            center = float(parts[0])
            err_low = float(parts[1])
            err_u = float(parts[1])
        else:
            center = float(parts[0])
            err_low = float(parts[1])
            err_u = float(parts[2])
        return center, err_low, err_u
    elif '<' in value_str:
        val = float(value_str.replace('<', '').strip())
        return val, val * 0.5, val
    elif '>' in value_str:
        val = float(value_str.replace('>', '').strip())
        return val, val, val * 1.5
    else:
        val = float(value_str)
        return val, val, val

def parse_range(value_str):
    value_str = value_str.strip()
    if '-' in value_str:
        low, high = value_str.split('-')
        return float(low), float(high)
    else:
        raise ValueError(f"Expected a range with '-' but got {value_str}")

# %%
fig=plot_energy_vs_gamma_beta(all_data)
# Out:
# 454 1454
# 454 -46
# 489 1489
# 489 -11
# 569 1569
# 569 69
# 663 1663
# 663 163
# 765 1765
# 765 265
# 871 1871
# 871 371
# 963 1963
# 963 463
# 1056 2056
# 1056 556
# 1140 2140
# 1140 640
# 454 1454
# 454 -46
# 489 1489
# 489 -11
# 569 1569
# 569 69
# 663 1663
# 663 163
# 765 1765
# 765 265
# 871 1871
# 871 371
# 963 1963
# 963 463
# 1056 2056
# 1056 556
# 1140 2140
# 1140 640
# 454 1454
# 454 -46
# 489 1489
# 489 -11
# 569 1569
# 569 69
# 663 1663
# 663 163
# 765 1765
# 765 265
# 871 1871
# 871 371
# 963 1963
# 963 463
# 1056 2056
# 1056 556
# 1140 2140
# 1140 640
# 454 1454
# 454 -46
# 489 1489
# 489 -11
# 569 1569
# 569 69
# 663 1663
# 663 163
# 765 1765
# 765 265
# 871 1871
# 871 371
# 963 1963
# 963 463
# 1056 2056
# 1056 556
# 1140 2140
# 1140 640

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# Define your custom styles
plot_style = {
    'GRBs':                     {'marker': 'o', 'alpha': 1, 'size': 70, 'zorder': 1, 'color': "tab:blue"},
    'Sub-E GRBs':               {'marker': 'o', 'alpha': 1, 'size': 70, 'zorder': 2, 'color': "lightblue"},
    'SNe':                      {'marker': 'o', 'alpha': 1, 'size': 70, 'zorder': 1, 'color': "dimgrey"},
    'LLAGN':                      {'marker': '^', 'alpha': 1, 'size': 90, 'zorder': 1, 'color': "purple"},
    # 'Rel-Sne':        {'marker': 'o', 'alpha': 1, 'size': 40, 'zorder': 2, 'color': "darkgrey"},
    'TDEs (jetted)':            {'marker': 's', 'alpha': 1, 'size': 60, 'zorder': 7, 'color': "darkgreen"},
    'TDEs':                     {'marker': 's', 'alpha': 1, 'size': 60, 'zorder': 7, 'color': "yellowgreen"},
    'Delayed TDEs':             {'marker': 's', 'alpha': 1, 'size': 60, 'zorder': 7, 'color': "darkseagreen"},
    'FBOTs':                    {'marker': 'D', 'alpha': 1, 'size': 60, 'zorder': 50, 'color': "black"},
    'ASKAP J0055-2558_sph': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "peru"},
    'ASKAP J0055-2558_c15': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "gold"},
    'ASKAP J0055-2558_c30': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "orange"},
    'ASKAP J0055-2558_c5': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "red"},
    "OA": {'marker': '*', 'alpha': 1, 'size': 250, 'zorder': 100,'color':"black"}
    # 'ASKAP J0055-2558_rel_c15': {'marker': '*', 'alpha': 1, 'size': 100, 'zorder': 100, 'color': "red"},
    # "ASKAP J0055-2558_non_rel": {'marker': 's', 'alpha': 1, 'size': 50, 'zorder': 100, 'color': "red"},
}
special_types_with_boxes = [] #["ASKAP J0055-2558_rel", "ASKAP J0055-2558_non_rel"]

def plot_energy_vs_gamma_beta(all_data):
    # fig = plt.figure(figsize=(6.5, 7))
    fig = plt.figure(figsize=(8, 7))
    ax = plt.gca()

    used_labels = set()

    for (obj_name, obj_type), group in all_data.groupby(['Name', 'Type']):
        style = plot_style.get(obj_type, {'marker': 'o', 'alpha': 0.7, 'size': 30, 'zorder': 1, 'color': 'gray'})

        gamma_beta_list = []
        energy_list = []

        for idx, row in group.iterrows():
            gamma_beta_raw = str(row['Gamma_beta'])
            energy_raw = str(row['Energy'])

            if obj_type in special_types_with_boxes:
                # Special case: draw dashed rectangle
                gamma_beta_low, gamma_beta_high = parse_range(gamma_beta_raw)
                energy_low, energy_high = parse_range(energy_raw)

                width = gamma_beta_high - gamma_beta_low
                height = energy_high - energy_low

                rect = mpatches.Rectangle(
                    (gamma_beta_low, energy_low),
                    width, height,
                    linewidth=1,
                    linestyle='-',  # Dashed rectangle
                    edgecolor=style['color'],
                    facecolor='none',
                    zorder=style['zorder']
                )
                ax.add_patch(rect)

            else:
                gamma_beta_val, gamma_beta_err_low, gamma_beta_err_high = parse_value_with_errors(gamma_beta_raw)
                energy_val, energy_err_low, energy_err_high = parse_value_with_errors(energy_raw)

                gamma_beta_list.append(gamma_beta_val)
                energy_list.append(energy_val)

                gamma_beta_arrow = None
                energy_arrow = None
                if '<' in gamma_beta_raw:
                    gamma_beta_arrow = 'left'
                elif '>' in gamma_beta_raw:
                    gamma_beta_arrow = 'right'
                if '<' in energy_raw:
                    energy_arrow = 'down'
                elif '>' in energy_raw:
                    energy_arrow = 'up'

                if gamma_beta_arrow is None and energy_arrow is None:
                    xerr = np.array([
                        [abs(gamma_beta_val - gamma_beta_err_low)],
                        [abs(gamma_beta_err_high - gamma_beta_val)]
                    ])
                    yerr = np.array([
                        [abs(energy_val - energy_err_low)],
                        [abs(energy_err_high - energy_val)]
                    ])

                    # Draw errorbars without marker
                    ax.errorbar(
                        gamma_beta_val, energy_val,
                        xerr=xerr,
                        yerr=yerr,
                        fmt='none',  # no marker at center
                        ecolor=style['color'],
                        elinewidth=1.5,
                        capsize=3,
                        alpha=style['alpha'],
                        zorder=style['zorder'] 
                    )

                    # Now separately scatter the point
                    ax.scatter(
                        gamma_beta_val, energy_val,
                        marker=style['marker'],
                        color=style['color'],
                        s=style['size'],
                        alpha=style['alpha'],
                        label=obj_type if obj_type not in used_labels else None,
                        zorder=style['zorder'],
                        edgecolor="black"
                    )

                else:
                    # Just scatter + big arrow for limits
                    ax.scatter(
                        gamma_beta_val, energy_val,
                        marker=style['marker'],
                        color=style['color'],
                        s=style['size'],
                        alpha=style['alpha'],
                        label=obj_type if obj_type not in used_labels else None,
                        zorder=style['zorder'],
                        edgecolor="black"
                    )

                    # Draw bigger arrows
                    arrow_dx = 0.4 * gamma_beta_val  # Make arrow longer (40% of x)
                    arrow_dy = 2 * energy_val  # Arrow longer (70% of y)

                    if gamma_beta_arrow:
                        if gamma_beta_arrow == 'left':
                            ax.annotate('', xy=(gamma_beta_val - arrow_dx, energy_val), xytext=(gamma_beta_val, energy_val),
                                        arrowprops=dict(arrowstyle="->", color=style['color'], lw=2))
                        else:
                            ax.annotate('', xy=(gamma_beta_val + arrow_dx, energy_val), xytext=(gamma_beta_val, energy_val),
                                        arrowprops=dict(arrowstyle="->", color=style['color'], lw=2))

                    if energy_arrow:
                        if energy_arrow == 'down':
                            ax.annotate('', xy=(gamma_beta_val, energy_val - arrow_dy), xytext=(gamma_beta_val, energy_val),
                                        arrowprops=dict(arrowstyle="->", color=style['color'], lw=2))
                        else:
                            ax.annotate('', xy=(gamma_beta_val, energy_val + arrow_dy), xytext=(gamma_beta_val, energy_val),
                                        arrowprops=dict(arrowstyle="->", color=style['color'], lw=2))

            used_labels.add(obj_type)

        # After plotting all points for one object, connect them
        if len(gamma_beta_list) >= 2:
            gamma_beta_list, energy_list = zip(*sorted(zip(gamma_beta_list, energy_list)))
            ax.plot(
                gamma_beta_list, energy_list,
                color=style['color'],
                lw=1.5,
                alpha=style['alpha'],
                zorder=style['zorder'] - 2  # Line below scatter
            )

        from datetime import datetime

        # Launch date
        launch_date = datetime(2022, 2, 4)

        # Dates corresponding to the three ASKAP observations
        # askap_obs_dates = [
        #     datetime(2024, 3, 10),
        #     datetime(2024, 6, 24),
        #     datetime(2024, 12, 26)
        # ]
        
        # Get unique date strings
        askap_obs_dates = np.unique(df_equi.dateobs)

        # Convert to datetime
        askap_obs_dates = pd.to_datetime(askap_obs_dates)

        # Shift amounts to apply
        time_shifts = [-1000]

        if obj_type.startswith('ASKAP J0055'):
            askap_row_counter = 0

            # Store shifted gamma*beta, epoch, and delta_t
            shifted_gamma_beta_records = []

            for idx, row in group.iterrows():
                gamma_beta_raw = str(row['Gamma_beta'])
                energy_raw = str(row['Energy'])

                gamma_beta_val, gamma_beta_err_low, gamma_beta_err_high = parse_value_with_errors(gamma_beta_raw)
                energy_val, energy_err_low, energy_err_high = parse_value_with_errors(energy_raw)

                obs_date = askap_obs_dates[askap_row_counter]
                t_original = (obs_date - launch_date).days

                for delta in time_shifts:
                    t_shifted = t_original - delta
                    if t_shifted <= 0:
                        continue  # skip unphysical

                    gamma_beta_shifted = gamma_beta_val * (t_original / t_shifted)

                    # Save the shift info
                    shifted_gamma_beta_records.append({
                        'gamma_beta_shifted': gamma_beta_shifted,
                        'energy_val': energy_val,
                        'epoch': obs_date.strftime('%Y-%m-%d'),
                        'delta': delta,
                        'color': plot_style[obj_type]['color']
                    })

#                     # Plot small vertical tick
#                     ax.plot(
#                         [gamma_beta_shifted, gamma_beta_shifted],
#                         [energy_val*0.9, energy_val*1.1],
#                         color=plot_style[obj_type]['color'],
#                         lw=1.5,
#                         alpha=0.8
#                     )

#                     # Label the shift
#                     ax.text(
#                         gamma_beta_shifted,
#                         energy_val*1.15,
#                         f'{delta:+d} d',
#                         ha='center',
#                         va='bottom',
#                         fontsize=8,
#                         rotation=90,
#                         color=plot_style[obj_type]['color'],
#                         alpha=0.8
#                     )

                askap_row_counter += 1
#             # === After processing all three points for this geometry ===
#             if shifted_gamma_beta_records:
#                 # Find min and max shifted gamma*beta
#                 min_record = min(shifted_gamma_beta_records, key=lambda x: x['gamma_beta_shifted'])
#                 max_record = max(shifted_gamma_beta_records, key=lambda x: x['gamma_beta_shifted'])

#                 for record, pos in zip([min_record, max_record], ['min', 'max']):
#                     ax.axvline(
#                         x=record['gamma_beta_shifted'],
#                         color=record['color'],
#                         linestyle=':',
#                         lw=2,
#                         alpha=0.8,
#                         zorder=0
#                     )
#                     # Offset for label position (in log-space, because plot is log-log)
#                     x_offset_factor = 0.9 if record['delta'] > 0 else 1.1  # move left for +, right for -

#                     ax.text(
#                         record['gamma_beta_shifted'] * x_offset_factor,
#                         ax.get_ylim()[1] * 0.08,  # slightly below the top
#                         f"{record['delta']:+d}d",
#                         ha='center',
#                         va='bottom',
#                         fontsize=9,
#                         rotation=90,
#                         color=record['color'],
#                         alpha=0.9
#                     )
          # === After processing all three points for this geometry ===
            if shifted_gamma_beta_records:
                # Find the record with the maximum gamma*beta
                max_record = min(shifted_gamma_beta_records, key=lambda x: x['gamma_beta_shifted'])

                # Plot vertical line at max gamma*beta
                ax.axvline(
                    x=max_record['gamma_beta_shifted'],
                    color=max_record['color'],
                    linestyle='--',
                    lw=1.5,
                    alpha=1,
                    zorder=0
                )

                # Offset label in log-space
                x_offset_factor = 0.9 if max_record['delta'] > 0 else 0.85  # adjust to avoid overlap

                # Add label for the shift
                ax.text(
                    max_record['gamma_beta_shifted'] * x_offset_factor,
                    ax.get_ylim()[1] * 0.25,
                    f"{max_record['delta']:+d}d",
                    ha='center',
                    va='bottom',
                    fontsize=11,
                    rotation=90,
                    color=max_record['color'],
                    alpha=0.9
                )
    # Draw vertical line at Gamma_beta = 1
    ax.axvline(x=1, color='black', linestyle='--', linewidth=2, zorder=0)
    
    ax.errorbar(
        1e-2, 1e53,
        yerr=[[1e53 - 1e52], [1e54 - 1e53]],
        marker='*',
        alpha=1,
        markersize=15,
        zorder=100,
        color="grey",
        linewidth=0,  # remove line
        elinewidth=1.5,
        capsize=3
        )
    ax.text(0.26, 0.95, r"$\mathrm{low}\;\epsilon_e,$" r"$\mathrm{high}\;\epsilon_B$",
        transform=ax.transAxes,  # Coordinate relative to axes
        va='top', ha='center', fontsize=10, color='black')
    ax.text(0.26, 0.82, r"$\mathrm{high}\;\epsilon_e,$" r"$\mathrm{low}\;\epsilon_B$",
            transform=ax.transAxes,  # Coordinate relative to axes
            va='top', ha='center', fontsize=10, color='black')
    ax.text(0.26, 0.70, r"$\epsilon_e \approx \epsilon_B$",
            transform=ax.transAxes,  # Coordinate relative to axes
            va='top', ha='right', fontsize=10, color='black')

#     # Add labels for non-relativistic and relativistic regimes
    ax.text(0.05,0.05,r"Non-relativistic",horizontalalignment='left',verticalalignment='center', transform=ax.transAxes,color="black",fontsize="12",fontweight="bold")
    ax.text(0.75,0.05,r"Relativistic",horizontalalignment='left',verticalalignment='center', transform=ax.transAxes,color="black",fontsize="12",fontweight="bold")


   # Build the legend with colored markers instead of colored squares
    from matplotlib.lines import Line2D

    label_order = [
        'ASKAP J0055-2558_sph', 'ASKAP J0055-2558_c30',
        'ASKAP J0055-2558_c15', 'ASKAP J0055-2558_c5',
        'GRBs', 'Sub-E GRBs', 'SNe', 'FBOTs', 'OA',
        'TDEs (jetted)', 'TDEs', 'Delayed TDEs', 'LLAGN',
    ]

    handles = [
        Line2D(
            [], [], 
            marker=plot_style[label]['marker'],
            color='white',  # no line connecting the points
            markerfacecolor=plot_style[label]['color'],
            markeredgecolor='white',
            markersize=12,
            label=label
        )
        for label in label_order
        if label in used_labels  # only if label actually appeared in the plot
    ]

    ax.legend(
        handles=handles,
        loc='upper center',
        bbox_to_anchor=(0.5, -0.1),
        ncol=4,
        frameon=False,
        fontsize=11,
        handletextpad=0.5,
        columnspacing=1.5
    )

    
    # Set log scales
    ax.set_xscale('log')
    ax.set_yscale('log')

    ax.set_xlabel(r'$\Gamma \beta$', fontsize=16)
    ax.set_ylabel(r'Kinetic Energy (erg)', fontsize=16)

    ax.tick_params(axis='both', colors='black', direction='in', length=7, width=1, labelsize="large")
    ax.tick_params(axis='both', which="minor", colors='black', direction='in', length=5, width=1)

    ax.set_yscale('log')

    from matplotlib.ticker import LogLocator
    ax.yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(2, 10)*0.1, numticks=10))
    ax.yaxis.set_minor_formatter(plt.NullFormatter())

    ax.tick_params(axis='y', which='both', direction='in', length=5, width=1)
    ax.tick_params(axis='both', which="major", colors='black', direction='in', length=7, width=1)


    for spine in ax.spines.values():
        spine.set_linewidth(2.5)

    plt.tight_layout()
    # plt.show()
    return fig

def parse_value_with_errors(value_str):
    value_str = value_str.strip()
    if '/' in value_str:
        parts = value_str.split('/')
        if len(parts)==2:
            center = float(parts[0])
            err_low = float(parts[1])
            err_u = float(parts[1])
        else:
            center = float(parts[0])
            err_low = float(parts[1])
            err_u = float(parts[2])
        return center, err_low, err_u
    elif '<' in value_str:
        val = float(value_str.replace('<', '').strip())
        return val, val * 0.5, val
    elif '>' in value_str:
        val = float(value_str.replace('>', '').strip())
        return val, val, val * 1.5
    else:
        val = float(value_str)
        return val, val, val

def parse_range(value_str):
    value_str = value_str.strip()
    if '-' in value_str:
        low, high = value_str.split('-')
        return float(low), float(high)
    else:
        raise ValueError(f"Expected a range with '-' but got {value_str}")

# %%
fig=plot_energy_vs_gamma_beta(all_data)

# %%
import astropy.units as u
0.15*(u.rad).to(u.deg)
# Out:
# 8.594366926962348

# %%
fig.savefig("GW190814_interesting_source_energy_velocity.png",format="png", dpi=150,bbox_inches='tight')
fig.savefig("GW190814_interesting_source_energy_velocity.pdf",format="pdf", dpi=150,bbox_inches='tight')

# %%
#         if obj_type.startswith('ASKAP J0055'):
#             # Define assumed launch date
#             from datetime import datetime

#             launch_date = datetime(2022, 2, 4)

#             # Dates corresponding to the three ASKAP observations (in order)
#             askap_obs_dates = [
#                 datetime(2024, 3, 10),
#                 datetime(2024, 6, 24),
#                 datetime(2024, 12, 26)
#             ]

#             # Find this row's position within the group
#             askap_idx = list(group.index).index(idx)
#             obs_date = askap_obs_dates[askap_idx]
#             t_original = (obs_date - launch_date).days

#             # Shift launch by ±50/100/200 days and recompute Gamma*Beta
#             time_shifts = [-1000, -500, 500]

#             for delta in time_shifts:
#                 t_shifted = t_original - delta
#                 if t_shifted <= 0:
#                     continue  # skip unphysical

#                 gamma_beta_shifted = gamma_beta_val * (t_original / t_shifted)

#                 ax.annotate(
#                     '',
#                     xy=(gamma_beta_shifted, energy_val),
#                     xytext=(gamma_beta_val, energy_val),
#                     arrowprops=dict(
#                         arrowstyle='->',
#                         color=style['color'],
#                         lw=1.3,
#                         alpha=0.5
#                     )
#                 )
        
#         from datetime import datetime

#         # Define launch date
#         launch_date = datetime(2022, 2, 4)

#         # The three observation dates (in order)
#         askap_obs_dates = [
#             datetime(2024, 3, 10),
#             datetime(2024, 6, 24),
#             datetime(2024, 12, 26)
#         ]

#         # Time shifts you want to show
#         time_shifts = [-1000,500]  # Only extreme shifts for clarity

#         if obj_type.startswith('ASKAP J0055'):
#             # Get this row's corresponding observation date
#             askap_idx = list(group.index).index(idx)
#             obs_date = askap_obs_dates[askap_idx]
#             t_original = (obs_date - launch_date).days

#             for delta in time_shifts:
#                 t_shifted = t_original - delta
#                 print(t_original,t_shifted)
#                 if t_shifted <= 0:
#                     continue  # Skip invalid (negative) time since launch

#                 gamma_beta_shifted = gamma_beta_val * (t_original / t_shifted)

#                 # Plot a small vertical tick at shifted Gamma*Beta
#                 # ax.plot(
#                 #     [gamma_beta_shifted, gamma_beta_shifted],
#                 #     [energy_val*0.9, energy_val*1.1],  # Small vertical line
#                 #     color=style['color'],
#                 #     lw=1.5,
#                 #     alpha=0.8
#                 # )

#                 # Add text label for the shift
#                 ax.text(
#                     gamma_beta_shifted,
#                     energy_val*1.15,  # Slightly above the line
#                     f'{delta:+d} d',
#                     ha='center',
#                     va='bottom',
#                     fontsize=8,
#                     rotation=90,
#                     color=style['color'],
#                     alpha=0.8
#                 )

# %%
def E_eq_to_E(E_eq, eps_e, eps_b, case):
    eps = (eps_b / eps_e) / (6 / 11)
    if case == "Newtonian":
        E = E_eq * (((11/17) * (eps ** (-6/17))) + ((6/17) * (eps ** (11/17))))
        return E
    else:
        raise ValueError("Only 'Newtonian' case is implemented.")

# Given parameters
E_eq = 1e51  # example E_eq value in erg
eps_e_values = [0.1, 0.0005]
eps_b_values = [0.1, 0.01, 0.001]

# Compute and collect combinations
results = []
for eps_e in eps_e_values:
    for eps_b in eps_b_values:
        E = E_eq_to_E(E_eq, eps_e, eps_b, case="Newtonian")
        results.append((E, eps_e, eps_b))

# Sort by energy E
results_sorted = sorted(results, key=lambda x: x[0])

# Display results
for E, eps_e, eps_b in results_sorted:
    print(f"E = {E:.3e} erg | eps_e = {eps_e} | eps_b = {eps_b}")
# Out:
# E = 1.045e+51 erg | eps_e = 0.1 | eps_b = 0.1
# E = 1.227e+51 erg | eps_e = 0.0005 | eps_b = 0.001
# E = 1.295e+51 erg | eps_e = 0.1 | eps_b = 0.01
# E = 2.681e+51 erg | eps_e = 0.1 | eps_b = 0.001
# E = 3.811e+51 erg | eps_e = 0.0005 | eps_b = 0.01
# E = 1.618e+52 erg | eps_e = 0.0005 | eps_b = 0.1

# %%
all_data=all_data[all_data["Name"]=="SW1644+57"]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd

# --- Your ASKAP data is assumed to be in all_data ---

plot_style = {
    'GRBs': {'marker': 'o', 'alpha': 1, 'size': 70, 'zorder': 1, 'color': "tab:blue"},
    'Sub-E GRBs': {'marker': 'o', 'alpha': 1, 'size': 70, 'zorder': 2, 'color': "lightblue"},
    'SNe': {'marker': 'o', 'alpha': 1, 'size': 70, 'zorder': 1, 'color': "dimgrey"},
    'LLAGN': {'marker': 'X', 'alpha': 1, 'size': 90, 'zorder': 1, 'color': "purple"},
    'TDEs (jetted)': {'marker': 's', 'alpha': 1, 'size': 60, 'zorder': 7, 'color': "darkgreen"},
    'TDEs': {'marker': 's', 'alpha': 1, 'size': 60, 'zorder': 7, 'color': "yellowgreen"},
    'Delayed TDEs': {'marker': 's', 'alpha': 1, 'size': 60, 'zorder': 7, 'color': "darkseagreen"},
    'FBOTs': {'marker': 'D', 'alpha': 1, 'size': 60, 'zorder': 50, 'color': "black"},
    'ASKAP J0055-2558_sph': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "peru"},
    'ASKAP J0055-2558_c15': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "gold"},
    'ASKAP J0055-2558_c30': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "orange"},
    'ASKAP J0055-2558_c5': {'marker': '*', 'alpha': 1, 'size': 300, 'zorder': 100, 'color': "red"},
    "OA": {'marker': '*', 'alpha': 0.6, 'size': 100, 'zorder': 100, 'color': "black"}
}

special_types_with_boxes = []

def parse_value_with_errors(value_str):
    value_str = value_str.strip()
    if '/' in value_str:
        parts = value_str.split('/')
        if len(parts) == 2:
            center = float(parts[0])
            err = float(parts[1])
            return center, center - err, center + err
        elif len(parts) == 3:
            center = float(parts[0])
            err_low = float(parts[1])
            err_u = float(parts[2])
            return center, center - err_low, center + err_u
    elif '<' in value_str:
        val = float(value_str.replace('<', '').strip())
        return val, val * 0.5, val
    elif '>' in value_str:
        val = float(value_str.replace('>', '').strip())
        return val, val, val * 1.5
    else:
        val = float(value_str)
        return val, val, val

def parse_range(value_str):
    value_str = value_str.strip()
    if '-' in value_str:
        low, high = value_str.split('-')
        return float(low), float(high)
    else:
        raise ValueError(f"Expected a range with '-' but got {value_str}")

def plot_energy_vs_gamma_beta(all_data):
    fig = plt.figure(figsize=(7, 6))
    ax = plt.gca()
    used_labels = set()

    for (obj_name, obj_type), group in all_data.groupby(['Name', 'Type']):
        style = plot_style.get(obj_type, {'marker': 'o', 'alpha': 0.7, 'size': 30, 'zorder': 1, 'color': 'gray'})
        gamma_beta_list = []
        energy_list = []

        for _, row in group.iterrows():
            gamma_beta_raw = str(row['Gamma_beta'])
            energy_raw = str(row['Energy'])

            if obj_type in special_types_with_boxes:
                continue  # skipping boxed range types for now
            else:
                gamma_beta_val, _, _ = parse_value_with_errors(gamma_beta_raw)
                energy_val, _, _ = parse_value_with_errors(energy_raw)

                gamma_beta_list.append(gamma_beta_val)
                energy_list.append(energy_val)

                ax.scatter(
                    gamma_beta_val, energy_val,
                    marker=style['marker'],
                    color=style['color'],
                    s=style['size'],
                    alpha=style['alpha'],
                    label=obj_type if obj_type not in used_labels else None,
                    zorder=style['zorder'],
                    edgecolor="black"
                )

            used_labels.add(obj_type)

        # Connect points per object
        if len(gamma_beta_list) >= 2:
            gamma_beta_list, energy_list = zip(*sorted(zip(gamma_beta_list, energy_list)))
            ax.plot(
                gamma_beta_list, energy_list,
                color=style['color'],
                lw=1.5,
                alpha=style['alpha'],
                zorder=style['zorder'] - 2
            )

    ax.axvline(x=1, color='black', linestyle='--', linewidth=2, zorder=0)
    ax.text(0.35, 0.95, "Non-relativistic", transform=ax.transAxes, fontsize=12, fontweight="bold")
    ax.text(0.65, 0.95, "Relativistic", transform=ax.transAxes, fontsize=12, fontweight="bold")

    # Legend
    label_order = ['ASKAP J0055-2558_c5', 'ASKAP J0055-2558_c15', 'ASKAP J0055-2558_c30', 'ASKAP J0055-2558_sph']
    handles = [mpatches.Patch(color=plot_style[label]['color'], label=label)
               for label in label_order if label in used_labels]
    ax.legend(handles=handles, loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2, frameon=False, fontsize=11)

    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel(r'$\Gamma \beta$', fontsize=16)
    ax.set_ylabel(r'Kinetic Energy (erg)', fontsize=16)

    ax.tick_params(axis='both', colors='black', direction='in', length=7, width=1, labelsize="large")
    ax.set_yscale('log')

    from matplotlib.ticker import LogLocator
    ax.yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(2, 10) * 0.1, numticks=10))
    ax.yaxis.set_minor_formatter(plt.NullFormatter())

    for spine in ax.spines.values():
        spine.set_linewidth(2)

    plt.tight_layout()
    return fig

# --- Run the function and show the plot ---
askap_types = [
    'ASKAP J0055-2558_sph',
    'ASKAP J0055-2558_c15',
    'ASKAP J0055-2558_c30',
    'ASKAP J0055-2558_c5',
]
askap_data = all_data[all_data['Type'].isin(askap_types)]

# fig = plot_energy_vs_gamma_beta(askap_data)
from matplotlib.cm import tab10

fig, ax = plt.subplots(figsize=(7, 6))
colors = tab10.colors

# Plot points and fits per type
for i, obj_type in enumerate(askap_types):
    sub_data = askap_data[askap_data['Type'] == obj_type]
    x_vals, y_vals = [], []

    for _, row in sub_data.iterrows():
        gamma_beta_raw = str(row['Gamma_beta'])
        energy_raw = str(row['Energy'])

        if '<' in gamma_beta_raw or '>' in gamma_beta_raw or '<' in energy_raw or '>' in energy_raw:
            continue

        try:
            gamma_beta_val, _, _ = parse_value_with_errors(gamma_beta_raw)
            energy_val, _, _ = parse_value_with_errors(energy_raw)
            if gamma_beta_val > 0 and energy_val > 0:
                x_vals.append(np.log10(gamma_beta_val))
                y_vals.append(np.log10(energy_val))
        except:
            continue

    if len(x_vals) >= 2:
        x_vals = np.array(x_vals)
        y_vals = np.array(y_vals)
        (slope, intercept), cov = np.polyfit(x_vals, y_vals, deg=1, cov=True)
        slope_err = np.sqrt(cov[0, 0])

        # Print fit parameters
        print(f"{obj_type}: log10(E) = ({slope:.2f} ± {slope_err:.2f}) × log10(Γβ) + {intercept:.2f}")

        # Plot data points
        style = plot_style.get(obj_type, {'color': colors[i % len(colors)], 'marker': 'o'})
        gamma_beta_lin = 10**x_vals
        energy_lin = 10**y_vals

        ax.scatter(gamma_beta_lin, energy_lin, label=obj_type, color=style['color'],
                   s=style.get('size', 60), alpha=0.8, edgecolor="black", marker=style['marker'])

        # Plot fit line
        x_fit = np.logspace(min(x_vals) - 0.2, max(x_vals) + 0.2, 200)
        y_fit = 10**(slope * np.log10(x_fit) + intercept)
        ax.plot(x_fit, y_fit, linestyle='--', color=style['color'], alpha=0.8)

# Formatting
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$\Gamma \beta$', fontsize=16)
ax.set_ylabel(r'Kinetic Energy (erg)', fontsize=16)
ax.set_title("Energy vs Γβ with Fits per Geometry", fontsize=14)
ax.legend(fontsize=10)
ax.grid(True, which='both', ls='--', alpha=0.4)

plt.tight_layout()
plt.show()
# Out:
# ASKAP J0055-2558_sph: log10(E) = (-1.01 ± 0.88) × log10(Γβ) + 50.41
# ASKAP J0055-2558_c15: log10(E) = (-1.48 ± 1.21) × log10(Γβ) + 51.54
# ASKAP J0055-2558_c30: log10(E) = (-1.24 ± 1.04) × log10(Γβ) + 51.01
# ASKAP J0055-2558_c5: log10(E) = (-1.87 ± 1.50) × log10(Γβ) + 52.50
